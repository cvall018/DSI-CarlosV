# %% [markdown]
# # Linear Regression with Statsmodels and Scikit-Learn

# %% [markdown]
# Let's investigate the housing dataset with linear regression. We'll use two different packages and you can see examples for linear regression of each:
# * statsmodels -- [linear regression](http://statsmodels.sourceforge.net/devel/examples/#regression)
# * scikit-learn -- [linear regression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %% [markdown]
# ## Intro to Scikit-Learn
#
# Scikit-learn is a machine learning package for python that includes a huge array of models including linear regression. Scikit-learn includes a number of sample data sets including the Boston housing data set. (We could also load the data with pandas as in the last lesson.)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

from sklearn import datasets, linear_model, gaussian_process
from sklearn.metrics import mean_squared_error
data = datasets.load_boston()

print data.DESCR
# Out:
# Boston House Prices dataset
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %% [markdown]
# Let's take a minute to see what the data looks like.

# %%
print data.feature_names
print data.data[0]
print data.target[0]
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# [  6.32000000e-03   1.80000000e+01   2.31000000e+00   0.00000000e+00
#    5.38000000e-01   6.57500000e+00   6.52000000e+01   4.09000000e+00
#    1.00000000e+00   2.96000000e+02   1.53000000e+01   3.96900000e+02
#    4.98000000e+00]
# 24.0

# %% [markdown]
# Scikit-learn has already split off the house value data into the target variable. Let's see how to build a linear regression. First let's put the data into a data frame for convenience, and do a quick check to see that everything loaded correctly.

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(data.data, columns=data.feature_names)

# Put the target (housing value -- MEDV) in another DataFrame
targets = pd.DataFrame(data.target, columns=["MEDV"])

# Take a look at the first few rows
print df.head()
print targets.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# Now let's fit a linear model to the data. First let's take a look at some of the variables we identified visually as being linked to house value, RM and LSTAT. Let's look at each individually and then both together.
#
# Note: If for some reason scikit-learn crashes the jupyter notebook, have conda remove mkl (there's an issue with the newer build on some systems).

# %%
lm = linear_model.LinearRegression(fit_intercept= False)

X = df[["RM"]]
y = targets["MEDV"]

model = lm.fit(X, y)
predictions = lm.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 58.4106354321

# %% [markdown]
# **Check**: How does this plot relate to the model? In other words, how are the independent variable (RM) and dependent variable ("MEDV") incorporated?

# %%
lm = linear_model.LinearRegression()

X = df[["LSTAT"]]
y = targets["MEDV"]

model = lm.fit(X, y)
predictions = lm.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from LSTAT")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 38.4829672299

# %%
lm = linear_model.LinearRegression(fit_intercept=False)

X = df[["RM", "LSTAT"]]
y = targets["MEDV"]

model = lm.fit(X, y)
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM and LSTAT")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 30.5235858483

# %% [markdown]
# ## Comparing the models
#
# A perfect fit would yield a straight line when we plot the predicted values versus the true values. We'll quantify the goodness of fit soon.
#
# ### Exercise
#
# Run the fit on all the variables with `X = df`. Did this improve the fit versus the previously tested variable combinations? (Use mean squared error).

# %%
lm = linear_model.LinearRegression()

X = df
y = targets["MEDV"]

model = lm.fit(X, y)
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from all Variables")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 21.8977792177

# %% [markdown]
# ## Guided Practice
#
# Compare this to the analgous fit from scikit-learn above.
#
# ### Exercises
#
# Recreate the model fits above with `statsmodels`:
# * a model using LSTAT
# * a model using RM and LSTAT
# * a model using all the variables
#
# Compare the mean squared errors for each model between the two packages. Do they differ significantly? Why or why not?

# %%
# Start your exercises here
X = df["LSTAT"]
y = targets["MEDV"]
X=sm.add_constant(X)#forces the model to include a B0

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from LSTAT")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 38.4829672299

# %%
# Start your exercises here
X = df[["RM", "LSTAT"]]
y = targets["MEDV"]
X=sm.add_constant(X)#forces the model to include a B0

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM and LSTAT")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 30.5124687773

# %%
import statsmodels.api as sm

X = df
y = targets["MEDV"]


# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from All Variables")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 24.1723662959

# %% [markdown]
# ## Independent Practice
#
# Using our preference of `scikit-learn` or `statsmodels`, try to find the best models that you can that:
# * use only two variables
# * only three variables
# * only four variables
#
# Evaluate your models using the squared error. Which has the lowest? How do the errors compare to using all the variables?

# %%
# Start your exercises here
import statsmodels.api as sm

X = df[["RM", "LSTAT"]]
y = targets["MEDV"]


# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM and LSTAT")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 30.5235858483

# %%
# Start your exercises here
import statsmodels.api as sm

X = df[["RM", "LSTAT",'DIS']]
y = targets["MEDV"]


# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM, LSTAT and CRIM")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 29.8597920982

# %%
# Start your exercises here
import statsmodels.api as sm

X = df
y = targets["MEDV"]


# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM, LSTAT, CRIM and DIS")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 24.1723662959

# %% [markdown]
# # Bonus Exercises
#
# From the LSTAT plot you may have noticed that the relationship is not quite linear. Add a new column `"LSTAT2"` to your data frame for the LSTAT values squared and try to fit a quadratic function using `["LSTAT", "LSTAT2"]`. Is the resulting fit better or worse?

# %%
# Start your exercises here
df["LSTAT2"]= df["LSTAT"].apply(lambda x: x**2.0)

# %%
lm = linear_model.LinearRegression()

X = df[["LSTAT", "LSTAT2"]]
y = targets["MEDV"]

model = lm.fit(X, y)
predictions = model.predict(X)

# Plot the model
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from all Variables")
plt.ylabel("Actual Values MEDV")
plt.show()
print "MSE:", mean_squared_error(y, predictions)
# Out:
# MSE: 30.3305200759

# %%
#Getting the best MSE of two variables out of many others
print data.feature_names
lst=[]
for i in data.feature_names:
    for j in data.feature_names:
        X=df[[i,j]]
        y=targets['MEDV']
        model=lm.fit(X,y)
        predictions=model.predict(X)
        print "For {} and {}, MSE : {}".format(i,j,mean_squared_error(y, predictions))
        lst.append(float(mean_squared_error(y,predictions)))
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# For CRIM and CRIM, MSE : 71.8523466653
# For CRIM and ZN, MSE : 64.7868339628
# For CRIM and INDUS, MSE : 61.0157201096
# For CRIM and CHAS, MSE : 69.8460543498
# For CRIM and NOX, MSE : 64.6056480683
# For CRIM and RM, MSE : 38.7888964105
# For CRIM and AGE, MSE : 66.2327955018
# For CRIM and DIS, MSE : 70.7846502609
# For CRIM and RAD, MSE : 69.0903528824
# For CRIM and TAX, MSE : 64.2269828149
# For CRIM and PTRATIO, MSE : 57.3727456506
# For CRIM and B, MSE : 68.3782944363
# For CRIM and LSTAT, MSE : 38.1932963399
# For ZN and CRIM, MSE : 64.7868339628
# For ZN and ZN, MSE : 73.4516960948
# For ZN and INDUS, MSE : 63.4325901587
# For ZN and CHAS, MSE : 70.3776584715
# For ZN and NOX, MSE : 66.7573181198
# For ZN and RM, MSE : 41.6747159952
# For ZN and AGE, MSE : 69.7694568166
# For ZN and DIS, MSE : 73.4352045113
# For ZN and RAD, MSE : 66.675119424
# For ZN and TAX, MSE : 61.6342043467
# For ZN and PTRATIO, MSE : 60.0495353887
# For ZN and B, MSE : 67.0926983361
# For ZN and LSTAT, MSE : 38.1661232978
# For INDUS and CRIM, MSE : 61.0157201096
# For INDUS and ZN, MSE : 63.4325901587
# For INDUS and INDUS, MSE : 64.6662216411
# For INDUS and CHAS, MSE : 61.0798440277
# For INDUS and NOX, MSE : 63.9867289958
# For INDUS and RM, MSE : 39.1454832115
# For INDUS and AGE, MSE : 64.0546450365
# For INDUS and DIS, MSE : 63.2158857525
# For INDUS and RAD, MSE : 63.5174130774
# For INDUS and TAX, MSE : 62.141095757
# For INDUS and PTRATIO, MSE : 54.3807815487
# For INDUS and B, MSE : 62.1651834994
# For INDUS and LSTAT, MSE : 38.2878328673
# For CHAS and CRIM, MSE : 69.8460543498
# For CHAS and ZN, MSE : 70.3776584715
# For CHAS and INDUS, MSE : 61.0798440277
# For CHAS and CHAS, MSE : 81.8265141193
# For CHAS and NOX, MSE : 65.0972877562
# For CHAS and RM, MSE : 42.5363642952
# For CHAS and AGE, MSE : 68.748584714
# For CHAS and DIS, MSE : 75.7344110418
# For CHAS and RAD, MSE : 69.6141727532
# For CHAS and TAX, MSE : 63.7614554675
# For CHAS and PTRATIO, MSE : 61.5472902765
# For CHAS and B, MSE : 72.8933648976
# For CHAS and LSTAT, MSE : 36.9289743155
# For NOX and CRIM, MSE : 64.6056480683
# For NOX and ZN, MSE : 66.7573181198
# For NOX and INDUS, MSE : 63.9867289958
# For NOX and CHAS, MSE : 65.0972877562
# For NOX and NOX, MSE : 69.0046475347
# For NOX and RM, MSE : 39.2181167428
# For NOX and AGE, MSE : 68.2516835528
# For NOX and DIS, MSE : 67.7210612295
# For NOX and RAD, MSE : 67.0516255797
# For NOX and TAX, MSE : 63.894594771
# For NOX and PTRATIO, MSE : 53.0385110638
# For NOX and B, MSE : 66.1171008657
# For NOX and LSTAT, MSE : 38.4734886697
# For RM and CRIM, MSE : 38.7888964105
# For RM and ZN, MSE : 41.6747159952
# For RM and INDUS, MSE : 39.1454832115
# For RM and CHAS, MSE : 42.5363642952
# For RM and NOX, MSE : 39.2181167428
# For RM and RM, MSE : 43.6005517712
# For RM and AGE, MSE : 39.6539354591
# For RM and DIS, MSE : 42.5875853408
# For RM and RAD, MSE : 38.6943287589
# For RM and TAX, MSE : 37.0969973325
# For RM and PTRATIO, MSE : 37.0387879923
# For RM and B, MSE : 38.4736783781
# For RM and LSTAT, MSE : 30.5124687773
# For AGE and CRIM, MSE : 66.2327955018
# For AGE and ZN, MSE : 69.7694568166
# For AGE and INDUS, MSE : 64.0546450365
# For AGE and CHAS, MSE : 68.748584714
# For AGE and NOX, MSE : 68.2516835528
# For AGE and RM, MSE : 39.6539354591
# For AGE and AGE, MSE : 72.423980929
# For AGE and DIS, MSE : 72.2279584352
# For AGE and RAD, MSE : 67.7358408829
# For AGE and TAX, MSE : 63.6725671222
# For AGE and PTRATIO, MSE : 57.2501254018
# For AGE and B, MSE : 67.5822885453
# For AGE and LSTAT, MSE : 37.8816770924
# For DIS and CRIM, MSE : 70.7846502609
# For DIS and ZN, MSE : 73.4352045113
# For DIS and INDUS, MSE : 63.2158857525
# For DIS and CHAS, MSE : 75.7344110418
# For DIS and NOX, MSE : 67.7210612295
# For DIS and RM, MSE : 42.5875853408
# For DIS and AGE, MSE : 72.2279584352
# For DIS and DIS, MSE : 79.1463415861
# For DIS and RAD, MSE : 71.7064913086
# For DIS and TAX, MSE : 65.8872490473
# For DIS and PTRATIO, MSE : 61.0999881615
# For DIS and B, MSE : 72.8805909751
# For DIS and LSTAT, MSE : 36.9564820135
# For RAD and CRIM, MSE : 69.0903528824
# For RAD and ZN, MSE : 66.675119424
# For RAD and INDUS, MSE : 63.5174130774
# For RAD and CHAS, MSE : 69.6141727532
# For RAD and NOX, MSE : 67.0516255797
# For RAD and RM, MSE : 38.6943287589
# For RAD and AGE, MSE : 67.7358408829
# For RAD and DIS, MSE : 71.7064913086
# For RAD and RAD, MSE : 72.1248118808
# For RAD and TAX, MSE : 64.8971015768
# For RAD and PTRATIO, MSE : 60.3683852211
# For RAD and B, MSE : 69.3002444726
# For RAD and LSTAT, MSE : 38.4333672017
# For TAX and CRIM, MSE : 64.2269828149
# For TAX and ZN, MSE : 61.6342043467
# For TAX and INDUS, MSE : 62.141095757
# For TAX and CHAS, MSE : 63.7614554675
# For TAX and NOX, MSE : 63.894594771
# For TAX and RM, MSE : 37.0969973325
# For TAX and AGE, MSE : 63.6725671222
# For TAX and DIS, MSE : 65.8872490473
# For TAX and RAD, MSE : 64.8971015768
# For TAX and TAX, MSE : 65.8872753368
# For TAX and PTRATIO, MSE : 56.7570824445
# For TAX and B, MSE : 64.2098472513
# For TAX and LSTAT, MSE : 37.9406662321
# For PTRATIO and CRIM, MSE : 57.3727456506
# For PTRATIO and ZN, MSE : 60.0495353887
# For PTRATIO and INDUS, MSE : 54.3807815487
# For PTRATIO and CHAS, MSE : 61.5472902765
# For PTRATIO and NOX, MSE : 53.0385110638
# For PTRATIO and RM, MSE : 37.0387879923
# For PTRATIO and AGE, MSE : 57.2501254018
# For PTRATIO and DIS, MSE : 61.0999881615
# For PTRATIO and RAD, MSE : 60.3683852211
# For PTRATIO and TAX, MSE : 56.7570824445
# For PTRATIO and PTRATIO, MSE : 62.6522000138
# For PTRATIO and B, MSE : 57.4889187535
# For PTRATIO and LSTAT, MSE : 33.2060427883
# For B and CRIM, MSE : 68.3782944363
# For B and ZN, MSE : 67.0926983361
# For B and INDUS, MSE : 62.1651834994
# For B and CHAS, MSE : 72.8933648976
# For B and NOX, MSE : 66.1171008657
# For B and RM, MSE : 38.4736783781
# For B and AGE, MSE : 67.5822885453
# For B and DIS, MSE : 72.8805909751
# For B and RAD, MSE : 69.3002444726
# For B and TAX, MSE : 64.2098472513
# For B and PTRATIO, MSE : 57.4889187535
# For B and B, MSE : 75.0324292075
# For B and LSTAT, MSE : 38.090972639
# For LSTAT and CRIM, MSE : 38.1932963399
# For LSTAT and ZN, MSE : 38.1661232978
# For LSTAT and INDUS, MSE : 38.2878328673
# For LSTAT and CHAS, MSE : 36.9289743155
# For LSTAT and NOX, MSE : 38.4734886697
# For LSTAT and RM, MSE : 30.5124687773
# For LSTAT and AGE, MSE : 37.8816770924
# For LSTAT and DIS, MSE : 36.9564820135
# For LSTAT and RAD, MSE : 38.4333672017
# For LSTAT and TAX, MSE : 37.9406662321
# For LSTAT and PTRATIO, MSE : 33.2060427883
# For LSTAT and B, MSE : 38.090972639
# For LSTAT and LSTAT, MSE : 38.4829672299

# %%
min(lst)
# Out:
# 30.51246877729947

# %%
df.corr() #spits R values(Pearson's Coefficient)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.377365  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.452220 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# LSTAT2   0.457213 -0.323323  0.532496 -0.047605  0.530723 -0.545322  0.523764
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT    LSTAT2
# CRIM    -0.377904  0.622029  0.579564  0.288250 -0.377365  0.452220  0.457213
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995 -0.323323
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800  0.532496
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929 -0.047605
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879  0.530723
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808 -0.545322
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339  0.523764
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996 -0.448110
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676  0.451766
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993  0.494704
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044  0.302565
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087 -0.342612
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000  0.960573
# LSTAT2  -0.448110  0.451766  0.494704  0.302565 -0.342612  0.960573  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr())
