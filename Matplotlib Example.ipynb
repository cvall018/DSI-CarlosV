# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
% matplotlib notebook

# %%
df = pd.DataFrame(np.random.randn(50,4), columns=["a","b","c","d"])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.250468 -0.703512  0.276238  0.006357
# 1  1.364428 -0.160255  0.932290  0.573209
# 2 -0.321024 -0.435517  0.353036 -0.976681
# 3  1.663270 -0.537288  1.163729  0.201470
# 4 -1.591842 -2.457572 -1.439106 -0.794262
# 5 -0.396103  1.044526 -0.128357 -0.786583
# 6 -0.816427  2.078937 -0.453552  0.934171
# 7 -0.016740  0.133275  1.480514  2.051009
# 8 -0.204133 -0.877141 -0.438186  1.540210
# 9 -0.780859  0.804369 -0.253444 -0.216883

# %%
df.plot.scatter(x='a',y='b', c='r', s=(df['b']*100, df['a']*100), label= 'Interaction Between A and B', title= 'My Title \n' )
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.bar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
